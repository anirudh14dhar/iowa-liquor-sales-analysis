# %% [markdown]
# # Iowa Liquor Sales Predictive Analysis

# %% [markdown]
# - The state of **Iowa** publishes its class **E** license liquor sales data monthly at https://data.iowa.gov/Sales-Distribution/Iowa-Liquor-Sales/m3tr-qhgy
# - It contains more than $19M$ samples of the detailed transaction records from the liquor vendors to
# the various retail stores within the state, since $2012$.
# - The dataset records the rich interaction between the $\sim 300$ liquor vendors,
# $\sim 2400$ liquor stores
# (with their lat-long coordinates), selling $\sim 9.4K$ liquor products.

# %% [markdown]
# <img src="img/iowa_flag.jpg" height=400 width=400 align=left>

# %% [markdown]
# ### Scope of this Project

# %% [markdown]
# - Analyze the store and product data for retailer Hy-Vee
# - Store segmentation to find valuable store insights
# - Market basket analysis
# - Sales forecasting to predict future sales

# %% [markdown]
# ### Housekeeping

# %%
import missingno as msno
import numpy as np
import pandas as pd
import re
import sqlite3
import pandas as pd
import gc
from nltk import word_tokenize 
import warnings

# Suppress warnings
warnings.filterwarnings('ignore')

# %%
# Show all the columns in data frame
pd.set_option("display.max_columns", 120, 'display.max_rows', 500)

# %% [markdown]
# ### Load the data to a pandas data frame

# %%
# Import liquor sales data
df = pd.read_csv('data/Iowa_Liquor_Sales.csv')

# %%
# Import product details data
lqdetails = pd.read_csv('data/Iowa_Liquor_Products.csv')

# %%
# Removing white spaces from columns
df.columns = df.columns.str.replace(' ','')
lqdetails.columns = lqdetails.columns.str.replace(' ','')

# %%
# Filter sales data to Hy-Vee subset
lqsales = df[df['StoreName'].str.contains('Hy-Vee')]

# %%
lqsales.head(1)
# Out:
#   Invoice/ItemNumber        Date  StoreNumber  \
# 2    INV-28403900139  07/01/2020         2643
#
#                             StoreName           Address      City ZipCode  \
# 2  Hy-Vee Wine and Spirits / Waterloo  2126 Kimball Ave  Waterloo   50701
#
#   StoreLocation  CountyNumber      County   Category    CategoryName  \
# 2           NaN           7.0  BLACK HAWK  1012400.0  Irish Whiskies
#
#    VendorNumber         VendorName ItemNumber ItemDescription  Pack  \
# 2         370.0  PERNOD RICARD USA      15628         Jameson     6
#
#    BottleVolume(ml)  StateBottleCost  StateBottleRetail  BottlesSold  \
# 2              1750            32.48              48.72            2
#
#    Sale(Dollars)  VolumeSold(Liters)  VolumeSold(Gallons)
# 2          97.44                 3.5                 0.92

# %%
lqdetails.head(1)
# Out:
#   ItemNumber         CategoryName                           ItemDescription  \
# 0     901141  Special Order Items  Libertine Absinthe(French Absinthe) Mini
#
#    Vendor                 VendorName  BottleVolume(ml)  Pack  InnerPack  Age  \
# 0   885.0  YAHARA BAY DISTILLERS INC                50     6          1    0
#
#    Proof    ListDate  UPC             SCC  StateBottleCost  StateCaseCost  \
# 0    114  04/20/2012  NaN  10892060104050             4.82           28.9
#
#    StateBottleRetail  ReportDate
# 0               7.23  09/01/2021

# %%
# Drop the df dataframe and garbage collect
del [[df]]
gc.collect()
# Out:
# 33

# %% [markdown]
# ### Building the Liquor Sales Database

# %% [markdown]
# We will decompose the original dataframe into multiple SQlite tables in order to solve the data inconsistencies
# - Products
# - Product_Prices, recording the historical bottle price changes of the products
# - Vendors
# - Stores
# - Transactions(master table), which records the vendor number, store number, product (item number), transaction date, bottles sold, volume (either in gallons or in liters), sales amount.

# %% [markdown]
# ### Products

# %%
# Columns to be included in products table
cols = ['Date',
       'Category',
       'CategoryName',
       'ItemNumber',
       'ItemDescription',
       'Pack',
       'BottleVolume(ml)']

product = lqsales[cols].copy()
product['CategoryName'] = product['CategoryName'].str.lower()
product['ItemDescription'] = product['ItemDescription'].str.lower()
product['ItemNumber'] = product['ItemNumber'].apply(str)

# %%
# Check for CategoryName and Category association inconsistency
product.groupby(['Category', 'CategoryName']).agg({'Date':'count'}).sort_values(by=['CategoryName'])
# Out:
#                                                   Date
# Category  CategoryName
# 1031100.0 100 proof vodka                        30284
# 1022200.0 100% agave tequila                    135059
# 1062300.0 aged dark rum                          18891
# 1082010.0 amaretto - imported                       38
# 1101100.0 american alcohol                        7791
# 1081010.0 american amaretto                      19593
# 1051100.0 american brandies                     114739
# 1071100.0 american cocktails                    123759
# 1081300.0 american cordials & liqueur           111476
# 1081000.0 american cordials & liqueurs             917
# 1091100.0 american distilled spirit specialty     9626
# 1091000.0 american distilled spirits specialty     110
# 1041100.0 american dry gins                     175688
# 1031200.0 american flavored vodka               219864
# 1051010.0 american grape brandies                68358
# 1081400.0 american schnapps                     145810
# 1041300.0 american sloe gins                      1453
# 1041200.0 american sloe gins                      2667
# 1031000.0 american vodka                          1720
# 1031100.0 american vodkas                       462315
# 1081020.0 anisette                                 861
# 1081305.0 apple schnapps                         11393
# 1051100.0 apricot brandies                       12641
# 1062050.0 barbados rum                            5886
# 1051110.0 blackberry brandies                    18951
# 1011100.0 blended whiskies                      300157
# 1011400.0 bottled in bond bourbon                 3188
# 1011500.0 bottled in bond bourbon                 5079
# 1081312.0 butterscotch schnapps                  13547
# 1012100.0 canadian whiskies                     531304
# 1051120.0 cherry brandies                         4398
# 1081315.0 cinnamon schnapps                      12902
# 1070000.0 cocktails / rtd                          466
# 1071100.0 cocktails /rtd                        147435
# 1081030.0 coffee liqueurs                        29693
# 1081100.0 coffee liqueurs                        29181
# 1011600.0 corn whiskies                            260
# 1011700.0 corn whiskies                           4300
# 1081200.0 cream liqueurs                        182313
# 1081210.0 creme de almond                          752
# 1081220.0 dark creme de cacao                     3144
# 1701100.0 decanters & specialty packages         13355
# 1901100.0 delisted items                            29
# 1090000.0 distilled spirits specialty               80
# 1081700.0 distilled spirits specialty            24230
# 1041200.0 flavored gin                            4712
# 1041150.0 flavored gins                           5694
# 1062300.0 flavored rum                          106864
# 1062500.0 flavored rum                          112600
# 1062100.0 gold rum                               31601
# 1081317.0 grape schnapps                          4847
# 1081240.0 green creme de menthe                   3990
# 1501100.0 high proof beer - american                16
# 1701200.0 holiday vap                               12
# 1081015.0 imported amaretto                       4623
# 1082015.0 imported amaretto                         20
# 1052100.0 imported brandies                      49040
# 1082100.0 imported cordials & liqueur             1795
# 1082000.0 imported cordials & liqueurs          108427
# 1092100.0 imported distilled spirit specialty     5796
# 1092000.0 imported distilled spirits specialty      30
# 1042100.0 imported dry gins                     106647
# 1032200.0 imported flavored vodka                98540
# 1052010.0 imported grape brandies                39394
# 1081390.0 imported schnapps                      55790
# 1082200.0 imported schnapps                      62834
# 1032000.0 imported vodka                           489
# 1032080.0 imported vodka                        128929
# 1032230.0 imported vodka - cherry                    9
# 1032200.0 imported vodka - misc                 112829
# 1032100.0 imported vodkas                       128406
# 1091400.0 iowa distilleries                       1413
# 1011800.0 iowa distillery whiskies                  23
# 1012400.0 irish whiskies                         61292
# 1012300.0 irish whiskies                         37257
# 1062100.0 jamaica rum                             7817
# 1012400.0 japanese whisky                          169
# 1031110.0 low proof vodka                          938
# 1022300.0 mezcal                                  3085
# 1081900.0 misc. american cordials & liqueurs     48137
# 1082900.0 misc. imported cordials & liqueurs     97984
# 1051150.0 miscellaneous  brandies                 1891
# 1081380.0 miscellaneous schnapps                 14932
# 1022100.0 mixto tequila                          72910
# 1091200.0 neutral grain spirits                  10069
# 1091300.0 neutral grain spirits flavored         14087
# 1031090.0 other proof vodka                       1967
# 1051140.0 peach brandies                          5019
# 1081330.0 peach schnapps                         23527
# 1081300.0 peppermint schnapps                    42687
# 1062200.0 puerto rico & virgin islands rum      131449
# 1081335.0 raspberry schnapps                      5263
# 1081500.0 rock & rye                              1366
# 1081340.0 root beer schnapps                      4340
# 1082390.0 schnapps - imported                        2
# 1082300.0 schnapps - imported                        1
# 1012200.0 scotch whiskies                       162846
# 1011250.0 single barrel bourbon whiskies          5576
# 1011300.0 single barrel bourbon whiskies          8466
# 1012300.0 single malt scotch                     59368
# 1012210.0 single malt scotch                     46981
# 1081350.0 spearmint schnapps                      1012
# 1901200.0 special order items                     8877
# 1062310.0 spiced rum                            148551
# 1062400.0 spiced rum                            148543
# 1011200.0 straight bourbon whiskies             491258
# 1011600.0 straight rye whiskies                  35899
# 1011500.0 straight rye whiskies                  20394
# 1081355.0 strawberry schnapps                     5018
# 1070100.0 temporary  & specialty packages           14
# 1700000.0 temporary &  specialty packages         3644
# 1701100.0 temporary & specialty packages         38928
# 1011400.0 tennessee whiskies                     83079
# 1011300.0 tennessee whiskies                     66508
# 1022100.0 tequila                               161221
# 1081500.0 triple sec                             20225
# 1081400.0 triple sec                             20174
# 1081365.0 tropical fruit schnapps                 3861
# 1031080.0 vodka 80 proof                        371583
# 1031200.0 vodka flavored                        194852
# 1081370.0 watermelon schnapps                     6729
# 1081600.0 whiskey liqueur                       250578
# 1081230.0 white creme de cacao                    3449
# 1081250.0 white creme de menthe                   1280
# 1062200.0 white rum                              90520

# %%
# Check for ItemDescription and ItemNumber association inconsistency
product.groupby(['ItemNumber', 'ItemDescription']).agg({'Date':'count'}).sort_values(by=['ItemDescription'])
# Out:
#                                                     Date
# ItemNumber ItemDescription
# 928096     "beefeater ""24"""                          1
# 87413      "jose cuervo silver ""rolling stones"""    93
# 258        "rumchata ""gochatas"""                     1
# 73058      "rumchata ""minichatas"" creamer cups"    590
# 27081      (ri)1 rye                                 103
# ...                                                  ...
# 902803     zwack                                       2
# 67322      zwack                                       2
# 36296      zyr vodka                                  43
# 36297      zyr vodka                                   6
# 903502     zyr vodka                                   4
#
# [9595 rows x 1 columns]

# %%
# We will use the most recent CategoryName and ID association to solve the inconsistency
product['Date'] = pd.to_datetime(product['Date'], format='%m/%d/%Y')
product['Year'] = pd.DatetimeIndex(product['Date']).year
category = product.sort_values(['Year']).drop_duplicates(subset = ['Category'], keep = 'last')
temp = product.merge(category[['Category', 'CategoryName']], on = 'Category', how = 'left')
temp.drop(columns = 'CategoryName_x', inplace = True)
temp.rename(columns = {'CategoryName_y': 'CategoryName'}, inplace = True)
product = temp.copy()
product.head(1)
# Out:
#         Date   Category ItemNumber ItemDescription  Pack  BottleVolume(ml)  \
# 0 2020-07-01  1012400.0      15628         jameson     6              1750
#
#    Year    CategoryName
# 0  2020  irish whiskies

# %%
# We will use the most recent ItemDescription and ItemNumber association to solve the inconsistency
item = product.sort_values(['Year']).drop_duplicates(subset = ['ItemNumber'], keep = 'last')
temp = product.merge(item[['ItemNumber', 'ItemDescription']], on = 'ItemNumber', how = 'left')
temp.drop(columns = 'ItemDescription_x', inplace = True)
temp.rename(columns = {'ItemDescription_y': 'ItemDescription'}, inplace = True)
product = temp.copy()
product.head(1)
# Out:
#         Date   Category ItemNumber  Pack  BottleVolume(ml)  Year  \
# 0 2020-07-01  1012400.0      15628     6              1750  2020
#
#      CategoryName ItemDescription
# 0  irish whiskies         jameson

# %%
# We will also use the most commonly recorded bottle volume associated with an item
volume = product.groupby(['ItemNumber']).agg({'BottleVolume(ml)':'value_counts'}).rename(columns = {'BottleVolume(ml)':'count'}).reset_index()
volume['rank'] = volume.groupby(['ItemNumber'])['count'].rank(ascending = False)
volume = volume[volume['rank'] == 1]

# %%
volume = product.merge(volume[['ItemNumber', 'BottleVolume(ml)']], on = 'ItemNumber', how = 'left')
volume.drop(columns = 'BottleVolume(ml)_x', inplace = True)
volume.rename(columns = {'BottleVolume(ml)_y': 'BottleVolume'}, inplace = True)
product = volume.copy()
product.head(1)
# Out:
#         Date   Category ItemNumber  Pack  Year    CategoryName  \
# 0 2020-07-01  1012400.0      15628     6  2020  irish whiskies
#
#   ItemDescription  BottleVolume
# 0         jameson        1750.0

# %%
# Cleaned product dataframe
product = product[['ItemNumber', 'ItemDescription', 'Category', 'CategoryName', 'BottleVolume', 'Pack']]
product.drop_duplicates(keep = 'first', inplace = True)
product.shape
# Out:
# (10303, 6)

# %%
# Adding proof to the products table
product = product.merge(lqdetails[['ItemNumber', 'Proof']], on = 'ItemNumber', how = 'left')

# %%
product.head(1)
# Out:
#   ItemNumber ItemDescription   Category    CategoryName  BottleVolume  Pack  \
# 0      15628         jameson  1012400.0  irish whiskies        1750.0     6
#
#    Proof
# 0   80.0

# %%
# Create new feature "Segment" to broadly categorize the items
product['CategoryName'] = product['CategoryName'].apply(str)
product['Segment'] = np.where(product['CategoryName'].str.contains('rum'),'rum',
                     np.where(product['CategoryName'].str.contains('gin'),'gin', 
                     np.where(product['CategoryName'].str.contains('cocktail'), 'cocktail',
                     np.where(product['CategoryName'].str.contains('brandy|brandies'), 'brandy',
                     np.where(product['CategoryName'].str.contains('whisk|bourbon|scotch'), 'whisky',
                     np.where(product['CategoryName'].str.contains('tequila|mezcal'), 'tequila',
                     np.where(product['CategoryName'].str.contains('schnapps'), 'schnapps',
                     np.where(product['CategoryName'].str.contains('vodka'), 'vodka',
                     np.where(product['CategoryName'].str.contains('spirit'), 'spirit',
                     np.where(product['CategoryName'].str.contains('liqueur'), 'liqueur',
                     np.where(product['CategoryName'].str.contains('brandies'), 'brandy', 'others')))))))))))
product['Segment'].value_counts()
# Out:
# whisky      2475
# vodka       1961
# others      1701
# liqueur     1005
# rum          799
# tequila      651
# brandy       404
# cocktail     383
# spirit       341
# schnapps     316
# gin          267
# Name: Segment, dtype: int64

# %%
# Rename columns for consistency
product.rename(columns = {'ItemNumber':'ProductID', 'ItemDescription':'ProductName', 'Category':'CategoryID'}, inplace = True)
product = product[['ProductID', 'ProductName', 'CategoryID', 'CategoryName', 'Segment', 'BottleVolume', 'Pack', 'Proof']]

# %%
product.head(1)
# Out:
#   ProductID ProductName  CategoryID    CategoryName Segment  BottleVolume  \
# 0     15628     jameson   1012400.0  irish whiskies  whisky        1750.0
#
#    Pack  Proof
# 0     6   80.0

# %%
# CategoryName and Segment are predominantly the more important features and we will therefore leave the null values
product.isnull().sum(axis = 0)
# Out:
# ProductID         0
# ProductName       0
# CategoryID      223
# CategoryName      0
# Segment           0
# BottleVolume      9
# Pack              0
# Proof           924
# dtype: int64

# %%
product.shape
# Out:
# (10303, 8)

# %% [markdown]
# ### Vendors

# %%
# Columns to be included in the vendors table
cols = ['Date',
        'VendorNumber',
        'VendorName']

vendor = lqsales[cols].copy()

# %%
vendor['Date'] = pd.to_datetime(vendor['Date'], format='%m/%d/%Y')
vendor['Year'] = pd.DatetimeIndex(vendor['Date']).year

# %%
# We will use the most recent VendorName
name = vendor.sort_values(['Year']).drop_duplicates(subset = ['VendorNumber'], keep = 'last')
temp = vendor.merge(name[['VendorNumber', 'VendorName']], on = 'VendorNumber', how = 'left')
temp.drop(columns = 'VendorName_x', inplace = True)
temp.rename(columns = {'VendorName_y': 'VendorName'}, inplace = True)
vendor = temp[['VendorNumber', 'VendorName']]
vendor.drop_duplicates(inplace = True)

# %%
# Rename columns to maintain consistency across tables
vendor.rename(columns = {'VendorNumber': 'VendorID'}, inplace = True)

# %%
# Check for null values
vendor.isnull().sum(axis = 0)
# Out:
# VendorID      1
# VendorName    1
# dtype: int64

# %%
# Removing nulls as both VendorID/Name is null for the row
vendor.dropna(inplace = True)

# %%
vendor.shape
# Out:
# (311, 2)

# %%
vendor.head(1)
# Out:
#    VendorID         VendorName
# 0     370.0  PERNOD RICARD USA

# %% [markdown]
# ### Stores

# %%
# Columns to be included in Stores table
cols = ['StoreNumber',
        'StoreName',
        'City',
        'ZipCode',
        'StoreLocation',
        'CountyNumber',
        'County']

store = lqsales[cols].drop_duplicates(subset = ['StoreNumber'], keep = 'first').copy()
store.dropna(inplace = True)

# %%
# Check for null values
store.isnull().sum(axis = 0)
# Out:
# StoreNumber      0
# StoreName        0
# City             0
# ZipCode          0
# StoreLocation    0
# CountyNumber     0
# County           0
# dtype: int64

# %%
# Standradize the store names
store['StoreName'] = store['StoreName'].apply(lambda x: x.split('/')[0].strip())

def standardize(token):
    token = str(token)
    token = token.replace("``",'')
    token = token.replace('"','')
    token = re.sub("[,`'#.]",'',token)
    token = str(token).lower().replace(' and ',' & ')
    words = word_tokenize(token)
    words = [str(i).capitalize().strip() for i in words]
    words = ' '.join(words)
    words = words.replace('  ',' ')
    return words

for column in ['StoreName', 'City', 'County']:
    store[column] = store[column].apply(standardize)

# %%
# Round off ZipCode value and convert to string
store.loc[store['ZipCode'] == '712-2','ZipCode'] = '51529'
store.loc[store['ZipCode'] == '51529']
store['ZipCode'] = store['ZipCode'].apply(int).round().apply(str)

# %%
# Format the longitude and lattitude for StoreLocation
def coordinates(loc):
    if str(loc) != 'nan':
        loc = str(loc)
        loc = re.findall(r'[-]\d.*\d', loc)[0]
        lon, lat = loc.split(' ')
        lon = round(float(lon), 2)
        lat = round(float(lat), 2)
        location = [lon, lat]
    else:
        location = np.nan
    return location

store['StoreLocation'] = store['StoreLocation'].apply(coordinates)

# %%
# Split the logitude and lattitude coordinates
long = []
lat = []
for i in store['StoreLocation']:
    x, y = str(i).split(', ')
    long.append(float(x.replace('[','')))
    lat.append(float(y.replace(']','')))
    
store['long'] = long
store['lat'] = lat

store.drop('StoreLocation', axis = 1, inplace = True)
store.drop_duplicates(subset = ['StoreNumber'], keep = 'first')
# Out:
#           StoreNumber                                StoreName  \
# 9                2663                        Hy-vee Food Store
# 18               2647                                 Hy-vee 7
# 34               2565                   Hy-vee Food Store 1636
# 61               2662                    Hy-vee Wine & Spirits
# 64               2555                        Hy-vee Food Store
# 87               2571                      Hy-vee Food Store 2
# 93               2578                                   Hy-vee
# 123              2675                                 Hy-vee 2
# 154              2635                                 Hy-vee 4
# 203              2718               Hy-vee Waukon Dollar Fresh
# 205              2653                    Hy-vee Wine & Spirits
# 214              2613                      Hy-vee Food Store 1
# 257              2619                    Hy-vee Wine & Spirits
# 265              2567                         Hy-vee Drugstore
# 267              2593                        Hy-vee Food Store
# 280              2678                      Hy-vee Fast & Fresh
# 325              2562                        Hy-vee Food Store
# 373              2572                        Hy-vee Food Store
# 431              2673                                 Hy-vee 6
# 436              2552                      Hy-vee Food Store 3
# 441              2509                                   Hy-vee
# 450              2648                                 Hy-vee 4
# 453              2720                             Hy-vee Gas 3
# 467              2629                      Hy-vee Food Store 2
# 486              2543                      Hy-vee Food Store 1
# 544              2665                                   Hy-vee
# 554              2588                     Hy-vee Food & Drug 6
# 665              2505                    Hy-vee Wine & Spirits
# 716              2605                       Hy-vee Drugstore 5
# 760              2670                        Hy-vee Food Store
# 853              2651                                   Hy-vee
# 861              2594                        Hy-vee Food Store
# 905              2621                      Hy-vee Food Store 3
# 9193453         Urbandale   50322          77.0        Polk -93.74  41.63
# 9196292         Muscatine   52761          70.0   Muscatine -91.04  41.43
# 9196632        Fort Dodge   50501          94.0     Webster -94.16  42.50
# 9200569           Corydon   50060          93.0       Wayne -93.32  40.76
# 9203881      Cedar Rapids   52402          57.0        Linn -91.66  42.01
# 9221175      Charles City   50616          34.0       Floyd -92.67  43.07
# 20678085  West Des Moines   50266          25.0      Dallas -93.81  41.56
# 21948184           Waukee   50263          25.0      Dallas -93.88  41.62
# 21966965       Manchester   52057          28.0    Delaware -91.47  42.48
# 21967112       Coralville   52241          52.0     Johnson -91.61  41.72
# 22004319           Grimes   50111          77.0        Polk -93.78  41.69

# %%
# Clean up names for consistency across tables
store.rename(columns = {'StoreNumber':'StoreID', 'long':'Long', 'lat':'Lat'}, inplace = True)

# %%
store.shape
# Out:
# (163, 8)

# %%
store.head(1)
# Out:
#    StoreID          StoreName       City ZipCode  CountyNumber County   Long  \
# 9     2663  Hy-vee Food Store  Urbandale   50322          77.0   Polk -93.74
#
#      Lat
# 9  41.63

# %% [markdown]
# ### Price

# %%
# Columns to be included in the Price table
cols = ['ItemNumber',
        'Date',
        'StateBottleRetail',
        'StateBottleCost']

price = lqsales[cols].copy()
price['Date'] = pd.to_datetime(price['Date'])

# %%
# Consider the mean value for StateBottleRetail and StateBottleCost to handle the price variation across a day
price = price.groupby(['ItemNumber', 'Date']).agg({'StateBottleRetail':'mean', 'StateBottleCost':'mean'}).reset_index()

# %%
# Clean up names so that it's consistent between tables.
price.rename(columns = {'ItemNumber': 'ProductID'}, inplace = True)

# %%
# Check for nulls
price.isnull().sum(axis = 0)
# Out:
# ProductID            0
# Date                 0
# StateBottleRetail    3
# StateBottleCost      3
# dtype: int64

# %%
# Drop null values
price.dropna(inplace = True)

# %%
price.head(1)
# Out:
#   ProductID       Date  StateBottleRetail  StateBottleCost
# 0       101 2016-10-31              29.97            19.98

# %% [markdown]
# ### Transactions

# %%
# Columns to be included in Transactions table
cols = ['Invoice/ItemNumber',
        'StoreNumber',
        'VendorNumber',
        'ItemNumber',
        'Category',
        'Date',
        'BottlesSold',
        'VolumeSold(Gallons)',
        'Sale(Dollars)']

transaction = lqsales[cols].copy()
transaction['Date'] = pd.to_datetime(transaction['Date'])

# %%
# Clean up names for consistency between tables
transaction.rename(columns = {'Invoice/ItemNumber':'TransactionID',
                              'StoreNumber':'StoreID',
                              'VendorNumber':'VendorID',
                              'ItemNumber':'ProductID',
                              'Category':'CategoryID',
                              'VolumeSold(Gallons)':'Volume',
                              'Sale(Dollars)':'Sale'}, inplace = True)

# %%
# Checking for null values
# Null values will remain since mapping between CategoryID and ProductID exists in Products table 
# and the Products table itself contains null values for CategoryID
transaction.isnull().sum(axis = 0)
# Out:
# TransactionID       0
# StoreID             0
# VendorID            1
# ProductID           0
# CategoryID       5889
# Date                0
# BottlesSold         0
# Volume              0
# Sale                7
# dtype: int64

# %%
transaction.shape
# Out:
# (7235676, 9)

# %%
transaction.head(1)
# 2692        37954.0  1.410399e+08         1434  1.369800e+02  1.873911e+04
# 2693        72545.0  2.551851e+08         1950  1.602100e+02  1.878016e+04
# 2695        85475.0  3.256693e+08         7230  3.409500e+02  3.184706e+04
# 2696       218161.0  6.586451e+08        18991  1.213490e+03  8.655952e+04
# 2697       818045.0  2.973742e+09        22432  6.077420e+03  3.599101e+05
# 2698       101874.0  4.191757e+08         3554  1.955600e+02  2.577936e+04
# 2699        45397.0  1.615108e+08         3184  1.883900e+02  1.809500e+04
# 2700       643974.0  2.323493e+09        29197  8.623920e+03  4.604218e+05
# 2701        35606.0  1.247819e+08          751  6.362000e+01  5.177620e+03
# 2702       167582.0  5.901857e+08         5821  5.892600e+02  4.986565e+04
# 2703       107985.0  4.544142e+08         5413  3.142700e+02  3.401502e+04
# 2704       319918.0  1.257824e+09        16399  4.719850e+03  2.350873e+05
# 2705       298013.0  1.164855e+09        16807  5.012610e+03  2.158934e+05
# 2707       179409.0  7.082205e+08         8509  4.550600e+02  4.785643e+04
# 2708       217511.0  8.554867e+08        10271  6.222900e+02  5.721001e+04
# 2709       282715.0  1.001460e+09         8278  6.602600e+02  5.842673e+04
# 2710       111342.0  4.092577e+08         2040  1.422100e+02  1.490714e+04
# 2711       189681.0  6.927040e+08         4501  3.737700e+02  3.567242e+04
# 2712      1049746.0  4.022523e+09        37239  9.266960e+03  6.083900e+05
# 2713       242241.0  9.787049e+08        15551  4.783620e+03  2.331160e+05
# 2714       523615.0  1.986794e+09        20008  5.123520e+03  3.098225e+05
# 2715       195207.0  7.864901e+08        13656  3.653760e+03  1.835442e+05
# 2716       196577.0  7.909473e+08        12136  2.858910e+03  1.472190e+05
# 2717         9622.0  4.176080e+07          331  4.090000e+00  3.482050e+03
# 2718       226165.0  9.211914e+08        10663  3.159980e+03  1.603671e+05
# 2719        90111.0  3.601610e+08         4453  6.325400e+02  4.948185e+04
# 2720        65841.0  2.649542e+08         2903  2.249300e+02  2.660212e+04
# 2721       130994.0  5.273797e+08         2491  2.631500e+02  1.860784e+04
# 2723        21105.0  8.372080e+07         1149  1.304700e+02  1.329942e+04
# 6178       115798.0  4.120632e+08         4604  1.206370e+03  7.459722e+04
# 6181        18140.0  7.504090e+07          433  4.351000e+01  4.588310e+03
# 6189        99551.0  3.615281e+08         4043  1.149930e+03  6.534455e+04
# 6191        21631.0  9.011080e+07          910  1.498400e+02  1.182916e+04
# 6209       312775.0  1.103388e+09        12551  3.078400e+03  2.405950e+05

# %% [markdown]
# ### Sales

# %%
# Creating a sales table for analyzing store sales later
cols = ['ItemNumber',
        'ItemDescription',
        'Date',
        'Sale(Dollars)',
        'BottlesSold',
        'StoreNumber', 
        'StoreName',
        'CategoryName',
        'BottleVolume(ml)',
        'VendorNumber', 
        'VendorName',
        'County']

dfsales = lqsales[cols].copy()
dfsales['Date'] = pd.to_datetime(dfsales['Date'])

cols = ['ItemNumber',
        'Age', 
        'Proof']
dfitem = lqdetails[cols].copy()

cols = ['StoreID',
        'Long', 
        'Lat']
dfstore = store[cols].copy().rename(columns = {'StoreID':'StoreNumber'})

# %%
dfsales['ItemNumber'] = dfsales['ItemNumber'].apply(str)
dfitem['ItemNumber'] = dfitem['ItemNumber'].apply(str)
temp = dfsales.merge(dfitem[['ItemNumber', 'Age', 'Proof']], on = 'ItemNumber', how = 'left')

# %%
temp.head(1)
# Out:
#   ItemNumber ItemDescription       Date  Sale(Dollars)  BottlesSold  \
# 0      15628         Jameson 2020-07-01          97.44            2
#
#    StoreNumber                           StoreName    CategoryName  \
# 0         2643  Hy-Vee Wine and Spirits / Waterloo  Irish Whiskies
#
#    BottleVolume(ml)  VendorNumber         VendorName      County  Age  Proof
# 0              1750         370.0  PERNOD RICARD USA  BLACK HAWK  0.0   80.0

# %%
dfstore['StoreNumber'] = dfstore['StoreNumber'].apply(str)
temp['StoreNumber'] = temp['StoreNumber'].apply(str)
df = temp.merge(dfstore[['StoreNumber', 'Long', 'Lat']], on = 'StoreNumber', how = 'left')

# %%
df.head(1)
# Out:
#   ItemNumber ItemDescription       Date  Sale(Dollars)  BottlesSold  \
# 0      15628         Jameson 2020-07-01          97.44            2
#
#   StoreNumber                           StoreName    CategoryName  \
# 0        2643  Hy-Vee Wine and Spirits / Waterloo  Irish Whiskies
#
#    BottleVolume(ml)  VendorNumber         VendorName      County  Age  Proof  \
# 0              1750         370.0  PERNOD RICARD USA  BLACK HAWK  0.0   80.0
#
#    Long  Lat
# 0   NaN  NaN

# %%
sales = df.copy()
sales = sales.rename(columns = {'ItemNumber':'ProductID', 'ItemDescription':'ProductName', 'Sale(Dollars)':'Sale',  
                        'StoreNumber':'StoreID', 'BottleVolume(ml)':'BottleVolume', 'VendorNumber':'VendorID'})

# %% [markdown]
# ### The SQLite Database

# %%
# Setting up the database connection
conn = sqlite3.connect('IowaLiquorSales.db')
cursor = conn.cursor()

# %%
# Create the tables
cursor.execute('''CREATE TABLE Product
                (ProductID, ProductName, CategoryID, CategoryName, Segment, BottleVolume, Pack, Proof)''')

cursor.execute('''CREATE TABLE Price
                (ProductID, Date, StateBottleRetail, StateBottleCost)''')

cursor.execute('''CREATE TABLE Vendor
                (VendorID, VendorName)''')

cursor.execute('''CREATE TABLE Store
                (StoreID, StoreName, City, ZipCode, CountyNumber, County, Long, Lat)''')

cursor.execute('''CREATE TABLE Transactions
                (TransactionID, StoreID, VendorID, ProductID, CategoryID, Date, BottlesSold, Volume, Sale)''')

cursor.execute('''CREATE TABLE Sales
                (ProductID, ProductName, Date, Sale, BottlesSold, StoreID, StoreName, CategoryName, BottleVolume,
                VendorID, VendorName, County, Age, Proof, Long, Lat)''')

# %%
product.to_sql('Product', conn, if_exists = 'append', index = False)
price.to_sql('Price', conn, if_exists = 'append', index = False)
vendor.to_sql('Vendor', conn, if_exists = 'append', index = False)
store.to_sql('Store', conn, if_exists = 'append', index = False)
transaction.to_sql('Transactions', conn, if_exists = 'append', index = False)
sales.to_sql('Sales', conn, if_exists = 'append', index = False)

# %%
conn.commit()
conn.close()
